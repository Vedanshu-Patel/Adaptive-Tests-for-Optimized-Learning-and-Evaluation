# %% [markdown]
# # Clustering

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Research/r.csv')
dataset.head()
# Out:
#    field   difficulty  Time  cumulative average  PCA_procc  PCA2  id
# 0       3           5     2                  13          0   NaN   1
# 1       4           2     4                   7          0   NaN   2
# 2       3           2     1                   5          0   NaN   3
# 3       3           1     6                  14          0   NaN   4
# 4       2           2     6                   7          0   NaN   5

# %%
X = dataset.iloc[:, 0:2].values

# %%
X
# Out:
# array([[3, 5],
#        [4, 2],
#        [3, 2],
#        [3, 1],
#        [2, 2],
#        [2, 2],
#        [4, 5],
#        [7, 4],
#        [7, 2],
#        [3, 3],
#        [3, 5],
#        [7, 2],
#        [3, 1],
#        [3, 5],
#        [4, 3],
#        [2, 4],
#        [7, 2],
#        [4, 2],
#        [1, 2],
#        [5, 3],
#        [6, 4],
#        [6, 4],
#        [1, 2],
#        [6, 5],
#        [6, 5],
#        [7, 5],
#        [5, 3],
#        [7, 1],
#        [3, 1],
#        [5, 5],
#        [1, 2],
#        [3, 2],
#        [5, 3],
#        [3, 4],
#        [7, 1],
#        [3, 2],
#        [6, 4],
#        [3, 2],
#        [1, 2],
#        [7, 4],
#        [7, 5],
#        [6, 2],
#        [1, 5],
#        [4, 2],
#        [3, 3],
#        [5, 4],
#        [7, 3],
#        [2, 5],
#        [2, 3],
#        [6, 4],
#        [1, 1],
#        [2, 3],
#        [1, 1],
#        [1, 5],
#        [5, 3],
#        [1, 2],
#        [4, 2],
#        [7, 5],
#        [2, 1],
#        [4, 2],
#        [5, 3],
#        [1, 2],
#        [2, 1],
#        [3, 5],
#        [5, 5],
#        [5, 3],
#        [5, 3],
#        [6, 3],
#        [6, 3],
#        [6, 1],
#        [4, 2],
#        [2, 1],
#        [6, 3],
#        [2, 5],
#        [3, 1],
#        [3, 5],
#        [2, 3],
#        [2, 3],
#        [5, 3],
#        [5, 5],
#        [6, 4],
#        [2, 4],
#        [5, 4],
#        [4, 4],
#        [6, 2],
#        [6, 1],
#        [1, 3],
#        [6, 3],
#        [4, 2],
#        [4, 5],
#        [3, 1],
#        [4, 2],
#        [1, 1],
#        [3, 5],
#        [2, 1],
#        [5, 5],
#        [2, 3],
#        [3, 2],
#        [5, 2],
#        [5, 3],
#        [1, 2],
#        [1, 1],
#        [3, 3],
#        [2, 3],
#        [5, 3],
#        [1, 1],
#        [6, 5],
#        [1, 4],
#        [6, 3],
#        [1, 5],
#        [7, 3],
#        [1, 1],
#        [4, 1],
#        [2, 5],
#        [7, 4],
#        [4, 4],
#        [6, 3],
#        [1, 1],
#        [5, 5],
#        [7, 1],
#        [1, 3],
#        [3, 1],
#        [1, 1],
#        [2, 3],
#        [7, 2],
#        [1, 3],
#        [1, 5],
#        [1, 3],
#        [2, 5],
#        [6, 5],
#        [2, 4],
#        [5, 2],
#        [3, 4],
#        [4, 3],
#        [7, 2],
#        [3, 1],
#        [6, 4],
#        [5, 3],
#        [6, 4],
#        [5, 2],
#        [7, 3],
#        [2, 1],
#        [7, 1],
#        [1, 5],
#        [5, 5],
#        [5, 2],
#        [3, 5],
#        [6, 2],
#        [7, 5],
#        [6, 3],
#        [2, 5],
#        [1, 5],
#        [5, 1],
#        [3, 5],
#        [7, 1],
#        [6, 4],
#        [6, 2],
#        [4, 4],
#        [1, 4],
#        [3, 1],
#        [7, 2],
#        [1, 4],
#        [7, 4],
#        [4, 3],
#        [5, 4],
#        [1, 3],
#        [2, 5],
#        [1, 3],
#        [5, 3],
#        [5, 1],
#        [7, 3],
#        [3, 4],
#        [6, 5],
#        [1, 3],
#        [5, 3],
#        [1, 2],
#        [1, 4],
#        [2, 5],
#        [4, 5],
#        [4, 2],
#        [6, 2],
#        [6, 1],
#        [5, 4],
#        [2, 2],
#        [4, 3],
#        [2, 3],
#        [1, 2],
#        [6, 2],
#        [5, 2],
#        [1, 4],
#        [3, 5],
#        [2, 3],
#        [1, 1],
#        [4, 2],
#        [6, 2],
#        [2, 4],
#        [7, 5],
#        [4, 1],
#        [6, 1],
#        [4, 5],
#        [6, 2],
#        [5, 4],
#        [3, 1],
#        [5, 2],
#        [6, 3],
#        [5, 4],
#        [5, 5],
#        [6, 2],
#        [5, 4],
#        [6, 3],
#        [4, 1],
#        [3, 5],
#        [5, 5],
#        [3, 1],
#        [3, 2],
#        [2, 5],
#        [6, 4],
#        [7, 1],
#        [5, 2],
#        [1, 1],
#        [7, 1],
#        [3, 1],
#        [1, 2],
#        [4, 1],
#        [2, 3],
#        [1, 2],
#        [4, 5],
#        [3, 2],
#        [1, 5],
#        [4, 5],
#        [6, 2],
#        [4, 4],
#        [4, 4],
#        [6, 2],
#        [5, 2],
#        [6, 4],
#        [1, 2],
#        [1, 3],
#        [4, 2],
#        [4, 4],
#        [7, 2],
#        [7, 1],
#        [5, 5],
#        [5, 4],
#        [7, 5],
#        [1, 2],
#        [2, 4],
#        [2, 4],
#        [6, 4],
#        [6, 3],
#        [4, 2],
#        [7, 4],
#        [6, 5],
#        [5, 1],
#        [1, 4],
#        [6, 2],
#        [6, 4],
#        [1, 3],
#        [6, 5],
#        [3, 3],
#        [1, 2],
#        [1, 4],
#        [6, 3],
#        [3, 5],
#        [7, 4],
#        [6, 2],
#        [3, 5],
#        [1, 1],
#        [1, 4],
#        [2, 4],
#        [7, 3],
#        [1, 4],
#        [6, 5],
#        [4, 2],
#        [7, 1],
#        [2, 3],
#        [7, 4],
#        [1, 5],
#        [4, 4],
#        [6, 2],
#        [4, 3],
#        [7, 3],
#        [4, 5],
#        [3, 5],
#        [2, 5],
#        [4, 1],
#        [2, 2],
#        [5, 2],
#        [3, 3],
#        [1, 2],
#        [6, 2],
#        [2, 1],
#        [6, 1],
#        [2, 5],
#        [3, 5],
#        [6, 5],
#        [7, 1],
#        [4, 3],
#        [7, 4],
#        [5, 3],
#        [5, 3],
#        [1, 3],
#        [5, 3],
#        [5, 2],
#        [5, 4],
#        [3, 3],
#        [2, 5],
#        [3, 4],
#        [1, 5],
#        [3, 1],
#        [3, 2],
#        [5, 1],
#        [6, 5],
#        [1, 1],
#        [2, 5],
#        [5, 5],
#        [7, 5],
#        [5, 1],
#        [2, 5],
#        [5, 1],
#        [2, 3],
#        [5, 4],
#        [1, 3],
#        [4, 1],
#        [6, 3],
#        [5, 3],
#        [1, 3],
#        [4, 4],
#        [2, 1],
#        [7, 3],
#        [1, 4],
#        [5, 5],
#        [4, 4],
#        [7, 5],
#        [7, 4],
#        [1, 5],
#        [3, 5],
#        [6, 1],
#        [2, 4],
#        [3, 4],
#        [6, 4],
#        [1, 2],
#        [5, 5],
#        [6, 5],
#        [5, 3],
#        [6, 4],
#        [1, 4],
#        [5, 4],
#        [2, 2],
#        [4, 5],
#        [6, 5],
#        [5, 5],
#        [3, 4],
#        [1, 5],
#        [6, 1],
#        [2, 4],
#        [6, 1],
#        [4, 5],
#        [5, 1],
#        [4, 3],
#        [7, 1],
#        [7, 1],
#        [2, 3],
#        [3, 1],
#        [6, 1],
#        [2, 2],
#        [5, 4],
#        [4, 4],
#        [5, 5],
#        [3, 2],
#        [2, 2],
#        [1, 3],
#        [5, 5],
#        [6, 3],
#        [2, 5],
#        [4, 5],
#        [7, 4],
#        [6, 1],
#        [7, 3],
#        [5, 4],
#        [6, 2],
#        [4, 1],
#        [2, 2],
#        [6, 1],
#        [2, 4],
#        [1, 2],
#        [1, 2],
#        [7, 2],
#        [7, 3],
#        [5, 3],
#        [3, 1],
#        [7, 1],
#        [2, 4],
#        [7, 3],
#        [7, 2],
#        [4, 3],
#        [1, 5],
#        [4, 4],
#        [7, 3],
#        [6, 3],
#        [6, 1],
#        [7, 1],
#        [1, 1],
#        [2, 4],
#        [5, 3],
#        [2, 2],
#        [3, 5],
#        [6, 2],
#        [2, 1],
#        [6, 1],
#        [7, 5],
#        [5, 3],
#        [5, 5],
#        [3, 3],
#        [2, 3],
#        [7, 2],
#        [5, 3],
#        [7, 2],
#        [4, 4],
#        [3, 3],
#        [3, 3],
#        [6, 1],
#        [6, 1],
#        [2, 2],
#        [6, 4],
#        [1, 3],
#        [5, 2],
#        [1, 2],
#        [5, 5],
#        [4, 5],
#        [3, 5],
#        [2, 4],
#        [7, 1],
#        [4, 1],
#        [4, 2],
#        [5, 3],
#        [4, 1],
#        [7, 5],
#        [2, 3],
#        [1, 3],
#        [2, 3],
#        [3, 2],
#        [7, 1],
#        [4, 1],
#        [1, 4],
#        [5, 4],
#        [3, 2],
#        [3, 2],
#        [5, 3],
#        [1, 2],
#        [5, 5],
#        [5, 1],
#        [7, 2],
#        [7, 4],
#        [4, 3],
#        [2, 2],
#        [2, 1],
#        [4, 4],
#        [7, 1],
#        [4, 5],
#        [2, 3],
#        [7, 5],
#        [5, 1],
#        [4, 1],
#        [1, 5],
#        [5, 4],
#        [1, 4],
#        [1, 5],
#        [2, 5],
#        [5, 4],
#        [5, 2],
#        [1, 1],
#        [1, 3],
#        [5, 1],
#        [5, 1],
#        [1, 2],
#        [1, 3],
#        [7, 1],
#        [1, 3],
#        [1, 2],
#        [7, 2],
#        [7, 5],
#        [7, 3],
#        [1, 1],
#        [1, 2],
#        [4, 5],
#        [3, 5],
#        [5, 3],
#        [2, 2],
#        [3, 2],
#        [6, 2],
#        [7, 3],
#        [5, 1],
#        [7, 5],
#        [2, 3],
#        [1, 5],
#        [4, 1],
#        [6, 2],
#        [4, 1],
#        [6, 2]])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 1)
Y = pca.fit_transform(X)

# %%
Y
# Out:
# array([[-1.05724901],
#        [ 0.04950194],
#        [-0.94985713],
#        [-0.91405984],
#        [-1.9492162 ],
#        [-1.9492162 ],
#        [-0.05788993],
#        [ 2.97598457],
#        [ 3.04757915],
#        [-0.98565442],
#        [-1.05724901],
#        [ 3.04757915],
#        [-0.91405984],
#        [-1.05724901],
#        [ 0.01370465],
#        [-2.02081079],
#        [ 3.04757915],
#        [ 0.04950194],
#        [-2.94857527],
#        [ 1.01306372],
#        [ 1.9766255 ],
#        [ 1.9766255 ],
#        [-2.94857527],
#        [ 1.94082821],
#        [ 1.94082821],
#        [ 2.94018728],
#        [ 1.01306372],
#        [ 3.08337645],
#        [-0.91405984],
#        [ 0.94146914],
#        [-2.94857527],
#        [-0.94985713],
#        [ 1.01306372],
#        [-1.02145171],
#        [ 3.08337645],
#        [-0.94985713],
#        [ 1.9766255 ],
#        [-0.94985713],
#        [-2.94857527],
#        [ 2.97598457],
#        [ 2.94018728],
#        [ 2.04822008],
#        [-3.05596715],
#        [ 0.04950194],
#        [-0.98565442],
#        [ 0.97726643],
#        [ 3.01178186],
#        [-2.05660808],
#        [-1.98501349],
#        [ 1.9766255 ],
#        [-2.91277798],
#        [-1.98501349],
#        [-2.91277798],
#        [-3.05596715],
#        [ 1.01306372],
#        [-2.94857527],
#        [ 0.04950194],
#        [ 2.94018728],
#        [-1.91341891],
#        [ 0.04950194],
#        [ 1.01306372],
#        [-2.94857527],
#        [-1.91341891],
#        [-1.05724901],
#        [ 0.94146914],
#        [ 1.01306372],
#        [ 1.01306372],
#        [ 2.01242279],
#        [ 2.01242279],
#        [ 2.08401737],
#        [ 0.04950194],
#        [-1.91341891],
#        [ 2.01242279],
#        [-2.05660808],
#        [-0.91405984],
#        [-1.05724901],
#        [-1.98501349],
#        [-1.98501349],
#        [ 1.01306372],
#        [ 0.94146914],
#        [ 1.9766255 ],
#        [-2.02081079],
#        [ 0.97726643],
#        [-0.02209264],
#        [ 2.04822008],
#        [ 2.08401737],
#        [-2.98437257],
#        [ 2.01242279],
#        [ 0.04950194],
#        [-0.05788993],
#        [-0.91405984],
#        [ 0.04950194],
#        [-2.91277798],
#        [-1.05724901],
#        [-1.91341891],
#        [ 0.94146914],
#        [-1.98501349],
#        [-0.94985713],
#        [ 1.04886101],
#        [ 1.01306372],
#        [-2.94857527],
#        [-2.91277798],
#        [-0.98565442],
#        [-1.98501349],
#        [ 1.01306372],
#        [-2.91277798],
#        [ 1.94082821],
#        [-3.02016986],
#        [ 2.01242279],
#        [-3.05596715],
#        [ 3.01178186],
#        [-2.91277798],
#        [ 0.08529923],
#        [-2.05660808],
#        [ 2.97598457],
#        [-0.02209264],
#        [ 2.01242279],
#        [-2.91277798],
#        [ 0.94146914],
#        [ 3.08337645],
#        [-2.98437257],
#        [-0.91405984],
#        [-2.91277798],
#        [-1.98501349],
#        [ 3.04757915],
#        [-2.98437257],
#        [-3.05596715],
#        [-2.98437257],
#        [-2.05660808],
#        [ 1.94082821],
#        [-2.02081079],
#        [ 1.04886101],
#        [-1.02145171],
#        [ 0.01370465],
#        [ 3.04757915],
#        [-0.91405984],
#        [ 1.9766255 ],
#        [ 1.01306372],
#        [ 1.9766255 ],
#        [ 1.04886101],
#        [ 3.01178186],
#        [-1.91341891],
#        [ 3.08337645],
#        [-3.05596715],
#        [ 0.94146914],
#        [ 1.04886101],
#        [-1.05724901],
#        [ 2.04822008],
#        [ 2.94018728],
#        [ 2.01242279],
#        [-2.05660808],
#        [-3.05596715],
#        [ 1.0846583 ],
#        [-1.05724901],
#        [ 3.08337645],
#        [ 1.9766255 ],
#        [ 2.04822008],
#        [-0.02209264],
#        [-3.02016986],
#        [-0.91405984],
#        [ 3.04757915],
#        [-3.02016986],
#        [ 2.97598457],
#        [ 0.01370465],
#        [ 0.97726643],
#        [-2.98437257],
#        [-2.05660808],
#        [-2.98437257],
#        [ 1.01306372],
#        [ 1.0846583 ],
#        [ 3.01178186],
#        [-1.02145171],
#        [ 1.94082821],
#        [-2.98437257],
#        [ 1.01306372],
#        [-2.94857527],
#        [-3.02016986],
#        [-2.05660808],
#        [-0.05788993],
#        [ 0.04950194],
#        [ 2.04822008],
#        [ 2.08401737],
#        [ 0.97726643],
#        [-1.9492162 ],
#        [ 0.01370465],
#        [-1.98501349],
#        [-2.94857527],
#        [ 2.04822008],
#        [ 1.04886101],
#        [-3.02016986],
#        [-1.05724901],
#        [-1.98501349],
#        [-2.91277798],
#        [ 0.04950194],
#        [ 2.04822008],
#        [-2.02081079],
#        [ 2.94018728],
#        [ 0.08529923],
#        [ 2.08401737],
#        [-0.05788993],
#        [ 2.04822008],
#        [ 0.97726643],
#        [-0.91405984],
#        [ 1.04886101],
#        [ 2.01242279],
#        [ 0.97726643],
#        [ 0.94146914],
#        [ 2.04822008],
#        [ 0.97726643],
#        [ 2.01242279],
#        [ 0.08529923],
#        [-1.05724901],
#        [ 0.94146914],
#        [-0.91405984],
#        [-0.94985713],
#        [-2.05660808],
#        [ 1.9766255 ],
#        [ 3.08337645],
#        [ 1.04886101],
#        [-2.91277798],
#        [ 3.08337645],
#        [-0.91405984],
#        [-2.94857527],
#        [ 0.08529923],
#        [-1.98501349],
#        [-2.94857527],
#        [-0.05788993],
#        [-0.94985713],
#        [-3.05596715],
#        [-0.05788993],
#        [ 2.04822008],
#        [-0.02209264],
#        [-0.02209264],
#        [ 2.04822008],
#        [ 1.04886101],
#        [ 1.9766255 ],
#        [-2.94857527],
#        [-2.98437257],
#        [ 0.04950194],
#        [-0.02209264],
#        [ 3.04757915],
#        [ 3.08337645],
#        [ 0.94146914],
#        [ 0.97726643],
#        [ 2.94018728],
#        [-2.94857527],
#        [-2.02081079],
#        [-2.02081079],
#        [ 1.9766255 ],
#        [ 2.01242279],
#        [ 0.04950194],
#        [ 2.97598457],
#        [ 1.94082821],
#        [ 1.0846583 ],
#        [-3.02016986],
#        [ 2.04822008],
#        [ 1.9766255 ],
#        [-2.98437257],
#        [ 1.94082821],
#        [-0.98565442],
#        [-2.94857527],
#        [-3.02016986],
#        [ 2.01242279],
#        [-1.05724901],
#        [ 2.97598457],
#        [ 2.04822008],
#        [-1.05724901],
#        [-2.91277798],
#        [-3.02016986],
#        [-2.02081079],
#        [ 3.01178186],
#        [-3.02016986],
#        [ 1.94082821],
#        [ 0.04950194],
#        [ 3.08337645],
#        [-1.98501349],
#        [ 2.97598457],
#        [-3.05596715],
#        [-0.02209264],
#        [ 2.04822008],
#        [ 0.01370465],
#        [ 3.01178186],
#        [-0.05788993],
#        [-1.05724901],
#        [-2.05660808],
#        [ 0.08529923],
#        [-1.9492162 ],
#        [ 1.04886101],
#        [-0.98565442],
#        [-2.94857527],
#        [ 2.04822008],
#        [-1.91341891],
#        [ 2.08401737],
#        [-2.05660808],
#        [-1.05724901],
#        [ 1.94082821],
#        [ 3.08337645],
#        [ 0.01370465],
#        [ 2.97598457],
#        [ 1.01306372],
#        [ 1.01306372],
#        [-2.98437257],
#        [ 1.01306372],
#        [ 1.04886101],
#        [ 0.97726643],
#        [-0.98565442],
#        [-2.05660808],
#        [-1.02145171],
#        [-3.05596715],
#        [-0.91405984],
#        [-0.94985713],
#        [ 1.0846583 ],
#        [ 1.94082821],
#        [-2.91277798],
#        [-2.05660808],
#        [ 0.94146914],
#        [ 2.94018728],
#        [ 1.0846583 ],
#        [-2.05660808],
#        [ 1.0846583 ],
#        [-1.98501349],
#        [ 0.97726643],
#        [-2.98437257],
#        [ 0.08529923],
#        [ 2.01242279],
#        [ 1.01306372],
#        [-2.98437257],
#        [-0.02209264],
#        [-1.91341891],
#        [ 3.01178186],
#        [-3.02016986],
#        [ 0.94146914],
#        [-0.02209264],
#        [ 2.94018728],
#        [ 2.97598457],
#        [-3.05596715],
#        [-1.05724901],
#        [ 2.08401737],
#        [-2.02081079],
#        [-1.02145171],
#        [ 1.9766255 ],
#        [-2.94857527],
#        [ 0.94146914],
#        [ 1.94082821],
#        [ 1.01306372],
#        [ 1.9766255 ],
#        [-3.02016986],
#        [ 0.97726643],
#        [-1.9492162 ],
#        [-0.05788993],
#        [ 1.94082821],
#        [ 0.94146914],
#        [-1.02145171],
#        [-3.05596715],
#        [ 2.08401737],
#        [-2.02081079],
#        [ 2.08401737],
#        [-0.05788993],
#        [ 1.0846583 ],
#        [ 0.01370465],
#        [ 3.08337645],
#        [ 3.08337645],
#        [-1.98501349],
#        [-0.91405984],
#        [ 2.08401737],
#        [-1.9492162 ],
#        [ 0.97726643],
#        [-0.02209264],
#        [ 0.94146914],
#        [-0.94985713],
#        [-1.9492162 ],
#        [-2.98437257],
#        [ 0.94146914],
#        [ 2.01242279],
#        [-2.05660808],
#        [-0.05788993],
#        [ 2.97598457],
#        [ 2.08401737],
#        [ 3.01178186],
#        [ 0.97726643],
#        [ 2.04822008],
#        [ 0.08529923],
#        [-1.9492162 ],
#        [ 2.08401737],
#        [-2.02081079],
#        [-2.94857527],
#        [-2.94857527],
#        [ 3.04757915],
#        [ 3.01178186],
#        [ 1.01306372],
#        [-0.91405984],
#        [ 3.08337645],
#        [-2.02081079],
#        [ 3.01178186],
#        [ 3.04757915],
#        [ 0.01370465],
#        [-3.05596715],
#        [-0.02209264],
#        [ 3.01178186],
#        [ 2.01242279],
#        [ 2.08401737],
#        [ 3.08337645],
#        [-2.91277798],
#        [-2.02081079],
#        [ 1.01306372],
#        [-1.9492162 ],
#        [-1.05724901],
#        [ 2.04822008],
#        [-1.91341891],
#        [ 2.08401737],
#        [ 2.94018728],
#        [ 1.01306372],
#        [ 0.94146914],
#        [-0.98565442],
#        [-1.98501349],
#        [ 3.04757915],
#        [ 1.01306372],
#        [ 3.04757915],
#        [-0.02209264],
#        [-0.98565442],
#        [-0.98565442],
#        [ 2.08401737],
#        [ 2.08401737],
#        [-1.9492162 ],
#        [ 1.9766255 ],
#        [-2.98437257],
#        [ 1.04886101],
#        [-2.94857527],
#        [ 0.94146914],
#        [-0.05788993],
#        [-1.05724901],
#        [-2.02081079],
#        [ 3.08337645],
#        [ 0.08529923],
#        [ 0.04950194],
#        [ 1.01306372],
#        [ 0.08529923],
#        [ 2.94018728],
#        [-1.98501349],
#        [-2.98437257],
#        [-1.98501349],
#        [-0.94985713],
#        [ 3.08337645],
#        [ 0.08529923],
#        [-3.02016986],
#        [ 0.97726643],
#        [-0.94985713],
#        [-0.94985713],
#        [ 1.01306372],
#        [-2.94857527],
#        [ 0.94146914],
#        [ 1.0846583 ],
#        [ 3.04757915],
#        [ 2.97598457],
#        [ 0.01370465],
#        [-1.9492162 ],
#        [-1.91341891],
#        [-0.02209264],
#        [ 3.08337645],
#        [-0.05788993],
#        [-1.98501349],
#        [ 2.94018728],
#        [ 1.0846583 ],
#        [ 0.08529923],
#        [-3.05596715],
#        [ 0.97726643],
#        [-3.02016986],
#        [-3.05596715],
#        [-2.05660808],
#        [ 0.97726643],
#        [ 1.04886101],
#        [-2.91277798],
#        [-2.98437257],
#        [ 1.0846583 ],
#        [ 1.0846583 ],
#        [-2.94857527],
#        [-2.98437257],
#        [ 3.08337645],
#        [-2.98437257],
#        [-2.94857527],
#        [ 3.04757915],
#        [ 2.94018728],
#        [ 3.01178186],
#        [-2.91277798],
#        [-2.94857527],
#        [-0.05788993],
#        [-1.05724901],
#        [ 1.01306372],
#        [-1.9492162 ],
#        [-0.94985713],
#        [ 2.04822008],
#        [ 3.01178186],
#        [ 1.0846583 ],
#        [ 2.94018728],
#        [-1.98501349],
#        [-3.05596715],
#        [ 0.08529923],
#        [ 2.04822008],
#        [ 0.08529923],
#        [ 2.04822008]])

# %%
from sklearn.preprocessing import StandardScaler
se =StandardScaler()
Y=se.fit_transform(Y)

# %%
Y
# Out:
# array([[-0.51782387],
#        [ 0.02424527],
#        [-0.46522503],
#        [-0.44769208],
#        [-0.95469533],
#        [-0.95469533],
#        [-0.02835358],
#        [ 1.45759027],
#        [ 1.49265616],
#        [-0.48275798],
#        [-0.51782387],
#        [ 1.49265616],
#        [-0.44769208],
#        [-0.51782387],
#        [ 0.00671232],
#        [-0.98976122],
#        [ 1.49265616],
#        [ 0.02424527],
#        [-0.51782387],
#        [ 1.51018911],
#        [ 0.96811997],
#        [ 1.00318587],
#        [-0.01082063],
#        [-1.47923152],
#        [-0.44769208],
#        [ 1.49265616],
#        [-1.47923152],
#        [ 1.45759027],
#        [ 0.00671232],
#        [ 0.47864967],
#        [-1.46169857],
#        [-1.00729417],
#        [-1.46169857],
#        [ 0.49618262],
#        [ 0.53124852],
#        [ 1.47512322],
#        [-0.50029093],
#        [ 0.95058702],
#        [-1.46169857],
#        [ 0.49618262],
#        [-1.44416563],
#        [-1.47923152],
#        [-1.00729417],
#        [-0.02835358],
#        [ 0.02424527],
#        [ 1.00318587],
#        [ 1.02071881],
#        [ 0.47864967],
#        [-0.95469533],
#        [ 0.00671232],
#        [-0.97222828],
#        [-1.44416563],
#        [ 1.00318587],
#        [ 0.51371557],
#        [-1.47923152],
#        [-0.51782387],
#        [-0.97222828],
#        [-1.42663268],
#        [ 0.02424527],
#        [ 1.00318587],
#        [-0.98976122],
#        [ 1.44005732],
#        [ 0.04177822],
#        [ 1.02071881],
#        [-0.02835358],
#        [ 1.00318587],
#        [ 0.47864967],
#        [-0.44769208],
#        [ 0.51371557],
#        [ 0.98565292],
#        [ 0.47864967],
#        [ 0.46111672],
#        [ 1.00318587],
#        [ 0.47864967],
#        [ 0.98565292],
#        [ 0.04177822],
#        [-0.51782387],
#        [ 0.46111672],
#        [-0.44769208],
#        [-0.46522503],
#        [-1.00729417],
#        [ 0.96811997],
#        [ 1.51018911],
#        [ 0.51371557],
#        [-1.42663268],
#        [ 1.51018911],
#        [-0.44769208],
#        [-1.44416563],
#        [ 0.04177822],
#        [-0.97222828],
#        [-1.44416563],
#        [-0.02835358],
#        [-0.46522503],
#        [-1.49676447],
#        [-0.02835358],
#        [ 1.00318587],
#        [-0.01082063],
#        [-0.01082063],
#        [ 1.00318587],
#        [ 0.51371557],
#        [ 0.96811997],
#        [-1.44416563],
#        [-1.46169857],
#        [ 0.02424527],
#        [-0.01082063],
#        [ 1.49265616],
#        [ 1.51018911],
#        [ 0.46111672],
#        [ 0.47864967],
#        [ 1.44005732],
#        [-1.44416563],
#        [-0.98976122],
#        [-0.98976122],
#        [ 0.96811997],
#        [ 0.98565292],
#        [ 0.02424527],
#        [ 1.45759027],
#        [ 0.95058702],
#        [ 0.53124852],
#        [-1.47923152],
#        [ 1.00318587],
#        [ 0.96811997],
#        [-1.46169857],
#        [ 0.95058702],
#        [-0.48275798],
#        [-1.44416563],
#        [-1.47923152],
#        [ 0.98565292],
#        [-0.51782387],
#        [ 1.45759027],
#        [ 1.00318587],
#        [-0.51782387],
#        [-1.42663268],
#        [-1.47923152],
#        [-0.98976122],
#        [ 1.47512322],
#        [-1.47923152],
#        [ 0.95058702],
#        [ 0.02424527],
#        [ 1.51018911],
#        [-0.97222828],
#        [ 1.45759027],
#        [-1.49676447],
#        [-0.01082063],
#        [ 1.00318587],
#        [ 0.00671232],
#        [ 1.47512322],
#        [-0.02835358],
#        [-0.51782387],
#        [-1.00729417],
#        [ 0.04177822],
#        [-0.95469533],
#        [ 1.02071881],
#        [ 1.02071881],
#        [-0.95469533],
#        [ 0.96811997],
#        [-1.46169857],
#        [ 0.51371557],
#        [-1.44416563],
#        [ 0.46111672],
#        [-0.02835358],
#        [-0.51782387],
#        [-0.98976122],
#        [ 1.51018911],
#        [ 0.04177822],
#        [ 0.02424527],
#        [ 0.49618262],
#        [ 0.04177822],
#        [ 1.44005732],
#        [-0.97222828],
#        [-1.46169857],
#        [-0.97222828],
#        [-0.46522503],
#        [ 1.51018911],
#        [ 0.04177822],
#        [-1.47923152],
#        [ 0.47864967],
#        [-0.46522503],
#        [-0.46522503],
#        [ 0.49618262],
#        [-1.44416563],
#        [ 0.46111672],
#        [ 0.53124852],
#        [ 1.49265616],
#        [ 1.45759027],
#        [ 0.00671232],
#        [-0.95469533],
#        [-0.93716238],
#        [-0.01082063],
#        [ 1.51018911],
#        [-0.02835358],
#        [-0.97222828],
#        [ 1.44005732],
#        [ 0.53124852],
#        [ 0.04177822],
#        [-1.49676447],
#        [ 0.47864967],
#        [-1.47923152],
#        [-1.49676447],
#        [-1.00729417],
#        [ 0.47864967],
#        [ 0.51371557],
#        [-1.42663268],
#        [-1.46169857],
#        [ 0.53124852],
#        [ 0.53124852],
#        [-1.44416563],
#        [-1.46169857],
#        [ 1.51018911],
#        [-1.46169857],
#        [-1.44416563],
#        [ 1.49265616],
#        [ 1.44005732],
#        [ 1.47512322],
#        [-1.42663268],
#        [-1.44416563],
#        [-0.02835358],
#        [-0.51782387],
#        [ 0.49618262],
#        [-0.95469533],
#        [-0.46522503],
#        [ 1.00318587],
#        [ 1.47512322],
#        [ 0.53124852],
#        [ 1.44005732],
#        [-0.97222828],
#        [-1.49676447],
#        [ 0.04177822],
#        [ 1.00318587],
#        [ 0.04177822],
#        [ 1.00318587]])

# %%
dataset['PCA_procc']=Y

# %%
W = dataset.iloc[:, 2:4].values

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 1)
M = pca.fit_transform(W)
M
# Out:
# array([[-5.03097172e+00],
#        [ 1.02023208e+00],
#        [ 2.93951391e+00],
#        [-5.92394029e+00],
#        [ 1.07356995e+00],
#        [ 1.27263506e-01],
#        [ 4.01916504e+00],
#        [ 1.96653852e+00],
#        [ 1.02023208e+00],
#        [ 7.01809800e+00],
#        [ 5.17882298e+00],
#        [-1.92536301e+00],
#        [ 1.07356995e+00],
#        [ 6.99142906e+00],
#        [ 3.09952753e+00],
#        [ 1.96653852e+00],
#        [ 4.09917185e+00],
#        [-5.05764066e+00],
#        [-1.89869407e+00],
#        [-5.05764066e+00],
#        [ 7.04476694e+00],
#        [ 5.07214723e+00],
#        [-4.92429597e+00],
#        [ 4.17917866e+00],
#        [ 5.99178474e+00],
#        [ 4.17917866e+00],
#        [-3.00501414e+00],
#        [-4.97763385e+00],
#        [-2.92500733e+00],
#        [-3.89798271e+00],
#        [-2.84500052e+00],
#        [-6.81690886e+00],
#        [ 5.99178474e+00],
#        [ 1.12690783e+00],
#        [ 2.01987640e+00],
#        [-4.87095810e+00],
#        [ 2.17989002e+00],
#        [-2.95167627e+00],
#        [-1.05906338e+00],
#        [-4.87095810e+00],
#        [-5.92394029e+00],
#        [-6.87024674e+00],
#        [-4.84428916e+00],
#        [ 4.99214042e+00],
#        [-1.95203195e+00],
#        [-4.03132740e+00],
#        [ 5.93844687e+00],
#        [ 6.17846730e+00],
#        [-5.89727135e+00],
#        [ 1.18024570e+00],
#        [ 2.09988321e+00],
#        [-5.81726454e+00],
#        [ 4.04583398e+00],
#        [-6.05728498e+00],
#        [-4.84428916e+00],
#        [ 4.93880255e+00],
#        [-1.03239444e+00],
#        [-2.81833158e+00],
#        [-2.87166946e+00],
#        [-5.92394029e+00],
#        [-1.97870088e+00],
#        [-3.87131378e+00],
#        [-4.97763385e+00],
#        [ 7.15144269e+00],
#        [-1.00572550e+00],
#        [-3.95132059e+00],
#        [ 3.01952072e+00],
#        [-1.87202514e+00],
#        [-5.81726454e+00],
#        [ 1.00594569e-01],
#        [ 1.18024570e+00],
#        [-6.03061604e+00],
#        [ 4.07250291e+00],
#        [ 1.10023889e+00],
#        [-1.05906338e+00],
#        [ 1.02023208e+00],
#        [-6.81690886e+00],
#        [ 4.12584079e+00],
#        [ 4.17917866e+00],
#        [ 6.04512262e+00],
#        [-3.81797590e+00],
#        [-3.27501172e-02],
#        [-5.95060923e+00],
#        [-5.87060242e+00],
#        [ 1.10023889e+00],
#        [-5.05764066e+00],
#        [-2.95167627e+00],
#        [-4.89762703e+00],
#        [ 3.12619647e+00],
#        [ 3.07285859e+00],
#        [ 7.15144269e+00],
#        [-5.92394029e+00],
#        [ 6.93809119e+00],
#        [ 3.93915823e+00],
#        [-4.05799634e+00],
#        [-6.00394710e+00],
#        [ 1.53932444e-01],
#        [-8.19042940e-01],
#        [-6.95025355e+00],
#        [ 1.18024570e+00],
#        [-7.05692930e+00],
#        [ 3.93915823e+00],
#        [ 5.07214723e+00],
#        [ 3.99249610e+00],
#        [-2.89833839e+00],
#        [ 5.96511581e+00],
#        [ 2.99285178e+00],
#        [ 7.09810481e+00],
#        [ 7.07143588e+00],
#        [ 1.27263506e-01],
#        [ 2.93951391e+00],
#        [-7.05692930e+00],
#        [-1.95203195e+00],
#        [-3.87131378e+00],
#        [ 3.99249610e+00],
#        [-8.45711877e-01],
#        [ 1.12690783e+00],
#        [ 2.99285178e+00],
#        [-4.87095810e+00],
#        [ 2.04654534e+00],
#        [ 1.18024570e+00],
#        [ 9.40225266e-01],
#        [-3.89798271e+00],
#        [-5.95060923e+00],
#        [ 5.93844687e+00],
#        [ 7.04476694e+00],
#        [ 3.15286541e+00],
#        [ 2.05877573e-02],
#        [ 1.07356995e+00],
#        [-6.00394710e+00],
#        [-5.97727817e+00],
#        [ 2.99285178e+00],
#        [-5.00430278e+00],
#        [ 1.10023889e+00],
#        [-4.03132740e+00],
#        [ 4.99214042e+00],
#        [ 2.93951391e+00],
#        [ 6.96476013e+00],
#        [-6.05728498e+00],
#        [-6.92358461e+00],
#        [-6.92358461e+00],
#        [-2.03203876e+00],
#        [-6.92358461e+00],
#        [-2.92500733e+00],
#        [ 5.99178474e+00],
#        [-2.84500052e+00],
#        [ 1.00594569e-01],
#        [-1.00572550e+00],
#        [ 1.96653852e+00],
#        [-4.00465846e+00],
#        [ 1.93986959e+00],
#        [ 6.04512262e+00],
#        [-1.03239444e+00],
#        [-7.05692930e+00],
#        [-5.03097172e+00],
#        [ 5.17882298e+00],
#        [ 9.66894203e-01],
#        [ 2.12655215e+00],
#        [-3.05835202e+00],
#        [-3.81797590e+00],
#        [-2.95167627e+00],
#        [-2.00536982e+00],
#        [-5.95060923e+00],
#        [-3.05835202e+00],
#        [-2.00536982e+00],
#        [ 5.07214723e+00],
#        [-1.03239444e+00],
#        [-2.92500733e+00],
#        [-1.95203195e+00],
#        [-4.84428916e+00],
#        [-2.95167627e+00],
#        [-7.00359142e+00],
#        [ 4.07250291e+00],
#        [ 1.93986959e+00],
#        [-3.89798271e+00],
#        [-9.79056563e-01],
#        [-7.00359142e+00],
#        [ 3.17953434e+00],
#        [-6.05728498e+00],
#        [-2.03203876e+00],
#        [-3.81797590e+00],
#        [-5.03097172e+00],
#        [ 6.09846049e+00],
#        [ 2.99285178e+00],
#        [ 5.04547830e+00],
#        [-2.05870770e+00],
#        [-2.95167627e+00],
#        [-6.05728498e+00],
#        [ 4.04583398e+00],
#        [-6.08117999e-03],
#        [-8.72380814e-01],
#        [ 5.17882298e+00],
#        [-5.84393348e+00],
#        [-6.84357780e+00],
#        [-1.03239444e+00],
#        [ 3.17953434e+00],
#        [ 1.53932444e-01],
#        [ 9.66894203e-01],
#        [ 4.01916504e+00],
#        [-8.45711877e-01],
#        [ 6.96476013e+00],
#        [ 6.09846049e+00],
#        [-5.81726454e+00],
#        [-2.05870770e+00],
#        [ 7.15144269e+00],
#        [-4.87095810e+00],
#        [-9.52387626e-01],
#        [-5.81726454e+00],
#        [-1.89869407e+00],
#        [ 4.04583398e+00],
#        [ 4.01916504e+00],
#        [ 7.12477375e+00],
#        [ 6.01845368e+00],
#        [-5.84393348e+00],
#        [ 3.01952072e+00],
#        [ 7.17811163e+00],
#        [-5.95060923e+00],
#        [ 1.96653852e+00],
#        [-6.08117999e-03],
#        [-1.00572550e+00],
#        [ 7.17811163e+00],
#        [ 6.17846730e+00],
#        [-7.05692930e+00],
#        [ 4.15250973e+00],
#        [-8.99049752e-01],
#        [-5.05764066e+00],
#        [-4.87095810e+00],
#        [-5.84393348e+00],
#        [ 4.99214042e+00],
#        [-5.00430278e+00],
#        [ 7.07143588e+00],
#        [-3.00501414e+00],
#        [-9.52387626e-01],
#        [ 4.01916504e+00],
#        [ 1.99320746e+00],
#        [-2.87166946e+00],
#        [ 2.01987640e+00],
#        [ 5.96511581e+00],
#        [-3.00501414e+00],
#        [-1.92536301e+00],
#        [ 1.00594569e-01],
#        [ 7.04476694e+00],
#        [-5.81726454e+00],
#        [ 6.15179837e+00],
#        [-6.03061604e+00],
#        [ 3.96582717e+00],
#        [-8.99049752e-01],
#        [-3.87131378e+00],
#        [ 4.17917866e+00],
#        [-6.08117999e-03],
#        [-1.89869407e+00],
#        [ 3.93915823e+00],
#        [-2.95167627e+00],
#        [-5.92394029e+00],
#        [-6.05728498e+00],
#        [ 6.04512262e+00],
#        [ 3.01952072e+00],
#        [ 1.12690783e+00],
#        [ 4.04583398e+00],
#        [-2.81833158e+00],
#        [ 1.10023889e+00],
#        [ 3.17953434e+00],
#        [-3.27501172e-02],
#        [-1.87202514e+00],
#        [ 6.99142906e+00],
#        [ 2.17989002e+00],
#        [ 5.93844687e+00],
#        [ 6.09846049e+00],
#        [-5.94190545e-02],
#        [ 1.53932444e-01],
#        [ 4.12584079e+00],
#        [ 3.07285859e+00],
#        [ 4.17917866e+00],
#        [ 4.09917185e+00],
#        [-3.27501172e-02],
#        [ 2.07321427e+00],
#        [-4.89762703e+00],
#        [-3.00501414e+00],
#        [-7.03026036e+00],
#        [-4.87095810e+00],
#        [-5.00430278e+00],
#        [-9.25718689e-01],
#        [ 2.17989002e+00],
#        [ 4.96547149e+00],
#        [ 7.12477375e+00],
#        [ 4.04583398e+00],
#        [ 1.93986959e+00],
#        [ 2.04654534e+00],
#        [-2.87166946e+00],
#        [ 6.96476013e+00],
#        [-2.89833839e+00],
#        [-2.92500733e+00],
#        [ 1.93986959e+00],
#        [-9.52387626e-01],
#        [ 1.10023889e+00],
#        [ 6.01845368e+00],
#        [-5.03097172e+00],
#        [-8.72380814e-01],
#        [ 6.96476013e+00],
#        [ 7.07143588e+00],
#        [ 7.01809800e+00],
#        [-6.97692249e+00],
#        [ 6.99142906e+00],
#        [-5.89727135e+00],
#        [ 5.07214723e+00],
#        [ 3.01952072e+00],
#        [ 3.04618966e+00],
#        [-6.08117999e-03],
#        [-5.92394029e+00],
#        [ 5.07214723e+00],
#        [ 4.15250973e+00],
#        [-3.84464484e+00],
#        [ 2.07321427e+00],
#        [ 3.04618966e+00],
#        [ 6.96476013e+00],
#        [-8.72380814e-01],
#        [-8.72380814e-01],
#        [ 4.93880255e+00],
#        [-4.00465846e+00],
#        [-1.81868726e+00],
#        [-3.87131378e+00],
#        [ 1.27263506e-01],
#        [-8.72380814e-01],
#        [ 5.09881617e+00],
#        [ 5.12548511e+00],
#        [-5.95060923e+00],
#        [ 4.96547149e+00],
#        [ 4.15250973e+00],
#        [-4.87095810e+00],
#        [ 6.17846730e+00],
#        [ 4.01916504e+00],
#        [-6.97692249e+00],
#        [ 2.09988321e+00],
#        [ 3.93915823e+00],
#        [ 5.12548511e+00],
#        [ 1.10023889e+00],
#        [ 4.96547149e+00],
#        [-4.97763385e+00],
#        [ 6.01845368e+00],
#        [ 9.93563141e-01],
#        [ 9.93563141e-01],
#        [ 4.93880255e+00],
#        [-5.05764066e+00],
#        [-6.03061604e+00],
#        [ 2.17989002e+00],
#        [-6.00394710e+00],
#        [ 1.02023208e+00],
#        [ 3.07285859e+00],
#        [ 1.02023208e+00],
#        [ 7.09810481e+00],
#        [ 2.12655215e+00],
#        [ 1.99320746e+00],
#        [ 7.09810481e+00],
#        [ 6.17846730e+00],
#        [-2.84500052e+00],
#        [ 5.09881617e+00],
#        [-3.87131378e+00],
#        [ 5.09881617e+00],
#        [ 1.80601381e-01],
#        [-4.03132740e+00],
#        [-4.89762703e+00],
#        [ 7.15144269e+00],
#        [ 1.12690783e+00],
#        [-3.89798271e+00],
#        [ 4.07250291e+00],
#        [ 1.10023889e+00],
#        [-1.89869407e+00],
#        [-2.84500052e+00],
#        [ 6.17846730e+00],
#        [ 2.01987640e+00],
#        [-2.87166946e+00],
#        [ 5.17882298e+00],
#        [ 1.04690102e+00],
#        [ 6.01845368e+00],
#        [-5.05764066e+00],
#        [ 5.17882298e+00],
#        [-5.89727135e+00],
#        [ 5.12548511e+00],
#        [-5.03097172e+00],
#        [ 1.96653852e+00],
#        [-2.84500052e+00],
#        [-3.92465165e+00],
#        [-5.94190545e-02],
#        [ 1.12690783e+00],
#        [ 2.93951391e+00],
#        [-4.84428916e+00],
#        [-2.97834520e+00],
#        [ 1.15357676e+00],
#        [ 5.12548511e+00],
#        [-9.25718689e-01],
#        [ 2.05877573e-02],
#        [-1.89869407e+00],
#        [-4.00465846e+00],
#        [ 1.10023889e+00],
#        [-5.92394029e+00],
#        [ 3.07285859e+00],
#        [-1.84535620e+00],
#        [ 6.99142906e+00],
#        [-6.05728498e+00],
#        [ 1.27263506e-01],
#        [-5.89727135e+00],
#        [-4.87095810e+00],
#        [-1.95203195e+00],
#        [-5.87060242e+00],
#        [ 1.10023889e+00],
#        [-9.79056563e-01],
#        [ 6.96476013e+00],
#        [ 9.66894203e-01],
#        [ 7.01809800e+00],
#        [-4.97763385e+00],
#        [ 1.07356995e+00],
#        [ 6.15179837e+00],
#        [ 9.93563141e-01],
#        [ 3.12619647e+00],
#        [ 3.09952753e+00],
#        [-3.97798953e+00],
#        [-1.89869407e+00],
#        [ 3.17953434e+00],
#        [-1.81868726e+00],
#        [-6.97692249e+00],
#        [ 4.15250973e+00],
#        [ 1.15357676e+00],
#        [ 1.07356995e+00],
#        [-7.03026036e+00],
#        [-3.87131378e+00],
#        [-4.05799634e+00],
#        [ 7.07143588e+00],
#        [-1.87202514e+00],
#        [-4.00465846e+00],
#        [ 4.99214042e+00],
#        [-6.00394710e+00],
#        [ 7.09810481e+00],
#        [-6.81690886e+00],
#        [ 4.07250291e+00],
#        [-6.03061604e+00],
#        [-4.87095810e+00],
#        [-6.89691568e+00],
#        [-4.89762703e+00],
#        [-1.03239444e+00],
#        [ 7.15144269e+00],
#        [ 6.15179837e+00],
#        [-4.87095810e+00],
#        [ 6.17846730e+00],
#        [-6.95025355e+00],
#        [ 2.04654534e+00],
#        [ 6.17846730e+00],
#        [-5.00430278e+00],
#        [ 2.93951391e+00],
#        [-5.84393348e+00],
#        [-1.81868726e+00],
#        [ 7.01809800e+00],
#        [ 3.15286541e+00],
#        [-2.84500052e+00],
#        [-6.95025355e+00],
#        [ 1.18024570e+00],
#        [-2.95167627e+00],
#        [ 3.17953434e+00],
#        [-5.89727135e+00],
#        [ 7.04476694e+00],
#        [-6.89691568e+00],
#        [-6.05728498e+00],
#        [ 9.40225266e-01],
#        [ 3.12619647e+00],
#        [ 4.72566945e-02],
#        [-1.84535620e+00],
#        [ 3.09952753e+00],
#        [ 4.17917866e+00],
#        [ 1.04690102e+00],
#        [-6.05728498e+00],
#        [ 3.04618966e+00],
#        [ 6.99142906e+00],
#        [ 3.96582717e+00],
#        [ 6.04512262e+00],
#        [ 1.96653852e+00],
#        [-4.81762022e+00],
#        [-2.81833158e+00],
#        [-3.92465165e+00],
#        [ 4.96547149e+00],
#        [ 6.07179156e+00],
#        [ 7.12477375e+00],
#        [-3.03168308e+00],
#        [-2.84500052e+00],
#        [-6.05728498e+00],
#        [-3.89798271e+00],
#        [-1.89869407e+00],
#        [-8.99049752e-01],
#        [-1.81868726e+00],
#        [-9.25718689e-01],
#        [-5.89727135e+00],
#        [-1.03239444e+00],
#        [ 1.04690102e+00],
#        [-4.95096491e+00],
#        [-1.89869407e+00],
#        [-5.05764066e+00],
#        [-5.84393348e+00],
#        [ 6.04512262e+00],
#        [ 4.99214042e+00],
#        [-4.95096491e+00],
#        [ 1.12690783e+00],
#        [-1.84535620e+00]])

# %%
from sklearn.preprocessing import StandardScaler
se =StandardScaler()
M=se.fit_transform(M)

# %%
M
# Out:
# array([[-1.14642970e+00],
#        [ 2.32484779e-01],
#        [ 6.69839987e-01],
#        [-1.34991438e+00],
#        [ 2.44639116e-01],
#        [ 2.90000960e-02],
#        [ 9.15864849e-01],
#        [ 4.48123799e-01],
#        [ 2.32484779e-01],
#        [ 1.59924492e+00],
#        [ 1.18012121e+00],
#        [-4.38740953e-01],
#        [ 2.44639116e-01],
#        [ 1.59316775e+00],
#        [ 7.06302997e-01],
#        [ 4.48123799e-01],
#        [ 9.34096353e-01],
#        [-1.15250686e+00],
#        [-4.32663785e-01],
#        [-1.15250686e+00],
#        [ 1.60532209e+00],
#        [ 1.15581254e+00],
#        [-1.12212102e+00],
#        [ 9.52327858e-01],
#        [ 1.36537439e+00],
#        [ 9.52327858e-01],
#        [-6.84765815e-01],
#        [-1.13427536e+00],
#        [-6.66534310e-01],
#        [-8.88250498e-01],
#        [-6.48302805e-01],
#        [-1.55339906e+00],
#        [ 1.36537439e+00],
#        [ 2.56793452e-01],
#        [ 4.60278136e-01],
#        [-1.10996669e+00],
#        [ 4.96741145e-01],
#        [-6.72611478e-01],
#        [-2.41333438e-01],
#        [-1.10996669e+00],
#        [-1.34991438e+00],
#        [-1.56555340e+00],
#        [-1.10388952e+00],
#        [ 1.13758104e+00],
#        [-4.44818122e-01],
#        [-9.18636339e-01],
#        [ 1.35322006e+00],
#        [ 1.40791457e+00],
#        [-1.34383721e+00],
#        [ 2.68947789e-01],
#        [ 4.78509641e-01],
#        [-1.32560571e+00],
#        [ 9.21942017e-01],
#        [-1.38030022e+00],
#        [-1.10388952e+00],
#        [ 1.12542670e+00],
#        [-2.35256270e-01],
#        [-6.42225637e-01],
#        [-6.54379973e-01],
#        [-1.34991438e+00],
#        [-4.50895290e-01],
#        [-8.82173330e-01],
#        [-1.13427536e+00],
#        [ 1.62963076e+00],
#        [-2.29179102e-01],
#        [-9.00404834e-01],
#        [ 6.88071492e-01],
#        [-4.26586617e-01],
#        [-1.32560571e+00],
#        [ 2.29229277e-02],
# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1,20):
  kmeans= KMeans(n_clusters = i, init = 'k-means++', random_state=42)
  kmeans.fit(Z)
  wcss.append(kmeans.inertia_)
plt.plot(range(1,20),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans= KMeans(n_clusters = 5, init = 'k-means++', random_state=40)
Y_predkmeans=kmeans.fit_predict(Z)

# %%
print(Y_predkmeans)
# Out:
# [3 4 0 3 0 3 2 4 4 0 0 4 0 0 2 0 2 1 3 1 2 2 3 2 2 2 1 1 3 1 3 3 2 0 4 3 4
#  3 3 1 1 1 3 2 3 1 2 0 3 4 0 3 0 3 1 0 4 1 3 1 4 3 3 0 4 1 2 4 1 4 4 3 2 0
#  3 0 3 0 2 2 1 3 1 1 4 1 3 1 2 2 0 1 0 0 3 1 3 3 1 4 3 0 0 0 1 0 2 0 2 3 2
#  3 4 3 2 4 4 0 1 4 0 0 3 3 2 0 0 3 0 1 3 2 3 4 1 0 2 2 1 1 1 3 1 3 2 1 3 4
#  4 1 0 0 4 3 1 2 4 4 3 3 1 3 1 1 4 0 3 3 4 1 1 3 2 0 1 3 3 0 1 4 1 1 2 0 2
#  3 3 1 2 3 3 0 3 1 4 0 4 4 2 4 2 2 3 4 2 1 4 1 4 2 2 0 2 3 0 0 1 4 4 3 2 0
#  3 2 3 3 1 3 0 1 2 1 4 2 4 1 0 0 1 4 4 2 1 2 1 0 3 3 2 4 4 2 1 1 3 2 2 0 2
#  3 0 0 4 3 2 4 0 0 3 3 2 0 2 2 4 0 1 3 1 1 1 4 4 0 0 2 0 4 3 0 1 3 4 3 0 2
#  1 4 2 2 2 3 2 1 2 0 0 3 3 0 0 1 4 0 0 4 4 2 3 4 3 4 3 2 2 1 0 2 3 2 0 1 4
#  2 2 0 0 1 0 0 4 0 1 1 4 1 0 2 0 2 4 4 0 0 1 0 1 2 4 1 1 2 0 3 2 0 4 1 2 0
#  3 0 4 2 3 2 1 2 1 4 1 1 3 4 0 3 3 4 2 4 3 4 3 4 1 2 3 2 1 4 1 1 3 3 4 3 0
#  4 0 1 4 2 4 0 0 1 4 2 4 3 0 4 4 3 1 3 2 3 1 2 3 0 1 2 1 1 1 1 3 0 0 3 2 1
#  0 2 3 0 1 3 2 2 1 1 4 3 0 1 2 1 3 4 2 4 3 2 0 0 3 2 2 0 0 4 1 3 3 2 0 0 1
#  1 1 3 3 4 3 4 3 3 4 1 4 1 3 0 2 1 4 4]

# %%
dataset['Cluster_label']=Y_predkmeans

# %%
dataset.head()
# Out:
#    field   difficulty  Time  cumulative average  PCA_procc      PCA2  id  \
# 0       3           5     2                  13  -0.517824 -1.146430   1
# 1       4           2     4                   7   0.024245  0.232485   2
# 2       3           2     1                   5  -0.465225  0.669840   3
# 3       3           1     6                  14  -0.447692 -1.349914   4
# 4       2           2     6                   7  -0.954695  0.244639   5
#
#    Cluster_label
# 0              3
# 1              4
# 2              0
# 3              3
# 4              0

# %%
plt.scatter(Z[Y_predkmeans==0,0], Z[Y_predkmeans==0,1], s=100, c='red' , label='cluster 1')
plt.scatter(Z[Y_predkmeans==1,0], Z[Y_predkmeans==1,1], s=100, c='blue' , label='cluster 2')
plt.scatter(Z[Y_predkmeans==2,0], Z[Y_predkmeans==2,1], s=100, c='green' , label='cluster 3')
plt.scatter(Z[Y_predkmeans==3,0], Z[Y_predkmeans==3,1], s=100, c='cyan' , label='cluster 4')
plt.scatter(Z[Y_predkmeans==4,0], Z[Y_predkmeans==4,1], s=100, c='magenta' , label='cluster 5')
plt.scatter(kmeans.cluster_centers_[:,0] ,kmeans.cluster_centers_[:,1], s=300, c='yellow', label='Centroids' )
plt.title('Cluster of Questions')
plt.xlabel('PCA_procc')
plt.ylabel('PCA2')
plt.legend(loc=4)
plt.show()

# %%
dataset
# Out:
#      field   difficulty  Time  cumulative average  PCA_procc      PCA2   id  \
# 0         3           5     2                  13  -0.517824 -1.146430    1
# 1         4           2     4                   7   0.024245  0.232485    2
# 2         3           2     1                   5  -0.465225  0.669840    3
# 3         3           1     6                  14  -0.447692 -1.349914    4
# 4         2           2     6                   7  -0.954695  0.244639    5
# ..      ...         ...   ...                 ...        ...       ...  ...
# 495       1           5     5                   2  -1.496764  1.377529  496
# 496       4           1     3                   3   0.041778  1.137581  497
# 497       6           2     5                  13   1.003186 -1.128198  498
# 498       4           1     8                   7   0.041778  0.256793  499
# 499       6           2     9                  10   1.003186 -0.420509  500
#
#      Cluster_label
# 0                3
# 1                4
# 2                0
# 3                3
# 4                0
# ..             ...
# 495              0
# 496              2
# 497              1
# 498              4
# 499              4
#
# [500 rows x 8 columns]

# %% [markdown]
# # RNN Part

# %%
dataset3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Research/r3.csv')
XX = dataset3.iloc[:,:5].values
YY = dataset3.iloc[:,5].values
ZZ = dataset3.iloc[:,0:6].values

# %%
XX_train,XX_test,YY_train,YY_test= train_test_split(XX,YY, test_size=0.3,random_state=0)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
n_input = 10
n_features = 6
generator = TimeseriesGenerator(ZZ,ZZ,length=n_input, batch_size=1)

# %%
XXXX,YYYY=generator[0]

# %%
XXXX
# Out:
# array([[[ 2.  ,  0.  ,  3.  ,  0.  ,  0.02,  3.  ],
#         [ 3.  , -1.  ,  2.  ,  1.  ,  0.05,  4.  ],
#         [ 4.  , -1.  ,  1.  ,  2.  ,  0.08,  2.  ],
#         [ 2.  ,  0.  ,  4.  ,  3.  ,  0.08,  1.  ],
#         [ 1.  ,  0.  ,  4.  ,  4.  ,  0.08,  2.  ],
#         [ 2.  ,  0.  ,  5.  ,  5.  ,  0.08,  3.  ],
#         [ 3.  ,  0.  ,  1.  ,  6.  ,  0.08,  4.  ],
#         [ 4.  ,  0.  ,  2.  ,  7.  ,  0.08,  5.  ],
#         [ 5.  ,  0.  ,  4.  ,  8.  ,  0.08,  5.  ],
#         [ 5.  , -1.  ,  1.  ,  9.  ,  0.18,  5.  ]]])

# %%
YYYY
# Out:
# array([[ 5.  ,  0.  ,  2.  , 10.  ,  0.18,  4.  ]])

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import tensorflow as tf

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(generator,epochs=50)
# Out:
# Epoch 1/50
# 41/41 [==============================] - 3s 11ms/step - loss: 131.2889
# Epoch 2/50
# 41/41 [==============================] - 0s 9ms/step - loss: 128.0154
# Epoch 3/50
# 41/41 [==============================] - 0s 9ms/step - loss: 127.8980
# Epoch 4/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8446
# Epoch 5/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.9913
# Epoch 6/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8642
# Epoch 7/50
# 41/41 [==============================] - 0s 5ms/step - loss: 127.8016
# Epoch 8/50
# 41/41 [==============================] - 0s 5ms/step - loss: 127.8021
# Epoch 9/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8807
# Epoch 10/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8138
# Epoch 11/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.7940
# Epoch 12/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8047
# Epoch 13/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.7922
# Epoch 14/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.7984
# Epoch 15/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8386
# Epoch 16/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.7945
# Epoch 17/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.7704
# Epoch 18/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.7995
# Epoch 19/50
# 41/41 [==============================] - 0s 7ms/step - loss: 127.7843
# Epoch 20/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8121
# Epoch 21/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8119
# Epoch 22/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.7919
# Epoch 23/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8404
# Epoch 24/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8184
# Epoch 25/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8050
# Epoch 26/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8373
# Epoch 27/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8083
# Epoch 28/50
# 41/41 [==============================] - 0s 5ms/step - loss: 127.7779
# Epoch 29/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8035
# Epoch 30/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.7813
# Epoch 31/50
# 41/41 [==============================] - 0s 5ms/step - loss: 127.7769
# Epoch 32/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.8047
# Epoch 33/50
# 41/41 [==============================] - 0s 6ms/step - loss: 127.7773
# Epoch 34/50
# 41/41 [==============================] - 0s 5ms/step - loss: 127.7726
# Epoch 35/50
# 41/41 [==============================] - 0s 5ms/step - loss: 127.7805
# Epoch 36/50
# 41/41 [==============================] - 0s 9ms/step - loss: 127.7969
# Epoch 37/50
# 41/41 [==============================] - 1s 12ms/step - loss: 127.8955
# Epoch 38/50
# 41/41 [==============================] - 1s 12ms/step - loss: 127.8121
# Epoch 39/50
# 41/41 [==============================] - 1s 18ms/step - loss: 127.7696
# Epoch 40/50
# 41/41 [==============================] - 1s 18ms/step - loss: 127.7944
# Epoch 41/50
# 41/41 [==============================] - 1s 15ms/step - loss: 127.7934
# Epoch 42/50
# 41/41 [==============================] - 1s 15ms/step - loss: 127.8209
# Epoch 43/50
# 41/41 [==============================] - 1s 12ms/step - loss: 127.7736
# Epoch 44/50
# 41/41 [==============================] - 1s 11ms/step - loss: 127.7744
# Epoch 45/50
# 41/41 [==============================] - 1s 16ms/step - loss: 127.7929
# Epoch 46/50
# 41/41 [==============================] - 1s 13ms/step - loss: 127.7624
# Epoch 47/50
# 41/41 [==============================] - 1s 13ms/step - loss: 127.7584
# Epoch 48/50
# 41/41 [==============================] - 0s 10ms/step - loss: 127.7576
# Epoch 49/50
# 41/41 [==============================] - 0s 10ms/step - loss: 127.7852
# Epoch 50/50
# 41/41 [==============================] - 0s 12ms/step - loss: 127.7654

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
import pandas as pd
dataset4=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Research/r3.csv')

# %%
dataset4.drop(['noq', 'penalties'], axis=1)
# Out:
#     cluster  result  time  Score
# 0         2       0     3      3
# 1         3      -1     2      4
# 2         4      -1     1      2
# 3         2       0     4      1
# 4         1       0     4      2
# 5         2       0     5      3
# 6         3       0     1      4
# 7         4       0     2      5
# 8         5       0     4      5
# 9         5      -1     1      5
# 10        5       0     2      4
# 11        4       0     3      5
# 12        5      -1     5      4
# 13        4      -1     2      3
# 14        3       0     4      4
# 15        4       0     2      4
# 16        4      -1     5      3
# 17        3       0     3      4
# 18        4       0     5      3
# 19        3      -1     4      2
# 20        2       0     5      2
# 21        3       0     4      4
# 22        4       0     5      4
# 23        4       0     2      5
# 24        5      -1     1      4
# 25        4      -1     4      3
# 26        3       0     4      3
# 27        3      -1     5      3
# 28        3      -1     2      2
# 29        2       0     5      2
# 30        2      -1     3      1
# 31        1       0     3      2
# 32        2      -1     4      1
# 33        1       0     5      1
# 34        1      -1     3      1
# 35        1      -1     2      1
# 36        1       0     3      1
# 37        1       0     2      2
# 38        2       0     2      3
# 39        3       0     5      3
# 40        3       0     2      4
# 41        4       0     4      4
# 42        5       0     3      5
# 43        5      -1     3      5
# 44        5      -1     4      4
# 45        4       0     5      4
# 46        4       0     3      3
# 47        3       0     5      3
# 48        3      -1     5      1
# 49        1       0     5      2
# 50        2       0     5      2

# %%
X4=dataset4.iloc[:,:-1].values
Y4=dataset4.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train4,X_test4,Y_train4,Y_test4 = train_test_split(X4,Y4, test_size=0.25, random_state=0)

# %%
# importing libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

# initializing the RNN
regressor = Sequential()

# adding first RNN layer and dropout regulatization
regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True, 
              input_shape = (X_train4.shape[1],1))
             )

regressor.add(
    Dropout(0.2)
             )


# adding second RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50, 
              activation = "tanh", 
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding third RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50, 
              activation = "relu", 
              return_sequences = True)
             )

regressor.add(
    Dropout(0.2)
             )

# adding fourth RNN layer and dropout regulatization

regressor.add(
    SimpleRNN(units = 50)
             )

regressor.add(
    Dropout(0.2)
             )

# adding the output layer
regressor.add(Dense(units = 1))

# compiling RNN
regressor.compile(
    optimizer = "adam", 
    loss = "mean_squared_error",
    metrics = ["accuracy"])

# fitting the RNN
history = regressor.fit(X_train4, Y_train4, epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 2/2 [==============================] - 4s 21ms/step - loss: 11.9318 - accuracy: 0.0789
# Epoch 2/10
# 2/2 [==============================] - 0s 19ms/step - loss: 5.3677 - accuracy: 0.1579
# Epoch 3/10
# 2/2 [==============================] - 0s 24ms/step - loss: 2.7691 - accuracy: 0.1579
# Epoch 4/10
# 2/2 [==============================] - 0s 18ms/step - loss: 2.4552 - accuracy: 0.1579
# Epoch 5/10
# 2/2 [==============================] - 0s 18ms/step - loss: 2.1682 - accuracy: 0.1579
# Epoch 6/10
# 2/2 [==============================] - 0s 17ms/step - loss: 2.3153 - accuracy: 0.1579
# Epoch 7/10
# 2/2 [==============================] - 0s 16ms/step - loss: 2.7265 - accuracy: 0.1579
# Epoch 8/10
# 2/2 [==============================] - 0s 17ms/step - loss: 2.3729 - accuracy: 0.1579
# Epoch 9/10
# 2/2 [==============================] - 0s 17ms/step - loss: 1.9022 - accuracy: 0.1579
# Epoch 10/10
# 2/2 [==============================] - 0s 16ms/step - loss: 2.0303 - accuracy: 0.1579

# %%
import matplotlib.pyplot as plt
# Plotting Loss vs Epochs
plt.figure(figsize =(10,7))
plt.plot(history.history["loss"])
plt.xlabel("Epochs")
plt.ylabel("Losses")
plt.title("Simple RNN model, Loss vs Epoch")
plt.show()

# %%
# Plotting Accuracy vs Epochs
plt.figure(figsize =(10,5))
plt.plot(history.history["accuracy"])
plt.xlabel("Epochs")
plt.ylabel("Accuracies")
plt.title("Simple RNN model, Accuracy vs Epoch")
plt.show()

# %%
y_pred = regressor.predict(X_train4)  # predictions

# %%
from keras.layers import LSTM

model_lstm = Sequential()
model_lstm.add(
    LSTM(64,return_sequences=True,input_shape = (X_train4.shape[1],1))) #64 lstm neuron block
model_lstm.add(
    LSTM(64, return_sequences= False))
model_lstm.add(Dense(32))
model_lstm.add(Dense(1))
model_lstm.compile(loss = "mean_squared_error", optimizer = "adam", metrics = ["accuracy","MeanSquaredError"])
history2 = model_lstm.fit(X_train4, Y_train4, epochs = 100, batch_size = 10)

# %%
#Jehan's cell
single_input = X_train4[5]
single_input = single_input.reshape(1, X_train4.shape[1], 1)
prediction = model_lstm.predict(single_input)
print(prediction)

# %%
X_train4[5]

# %%
X_train4

# %%
test_loss, test_acc, test_mse = model_lstm.evaluate(X_test4, Y_test4)
print("Test mean squared error:", test_mse)

# %% [markdown]
# # Rnn Final

# %%
import pandas as pd
dataset4=pd.read_csv('/content/r3 - Sheet1.csv')
dataset4=dataset4.drop(['noq'], axis=1)
X4=dataset4.iloc[:,:-1].values
Y4=dataset4.iloc[:,-1].values


from sklearn.model_selection import train_test_split
X_train4,X_test4,Y_train4,Y_test4 = train_test_split(X4,Y4, test_size=0.25, random_state=0)
from keras.layers import LSTM

model_lstm = Sequential()
model_lstm.add(
    LSTM(64,return_sequences=True,input_shape = (X_train4.shape[1],1))) #64 lstm neuron block
model_lstm.add(
    LSTM(64, return_sequences= False))
model_lstm.add(Dense(32))
model_lstm.add(Dense(1))
model_lstm.compile(loss = "mean_squared_error", optimizer = "adam", metrics = ["MeanSquaredError"])
history2 = model_lstm.fit(X_train4, Y_train4, epochs = 100, batch_size = 10)
test_loss, test_mse = model_lstm.evaluate(X_test4, Y_test4)

print("Test mean squared error:", test_mse)

# %%
X_train4.shape[1]

# %%
Y_pred = model_lstm.predict(X_test4)
Y_pred

# %%
import numpy as np
Y_pred = model_lstm.predict(X_test4)
result = np.concatenate((X_test4, Y_pred), axis=1)

# %% [markdown]
# # Running Rnn(Correct)

# %%
import pandas as pd
dataset4=pd.read_csv('/content/r4 cumulative.xlsx - Worksheet (1).csv')
dataset4=dataset4.drop(['noq'], axis=1)
X4=dataset4.iloc[:,:-1].values
Y4=dataset4.iloc[:,-1].values
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout
from keras.models import Sequential
from sklearn.model_selection import train_test_split
X_train4,X_test4,Y_train4,Y_test4 = train_test_split(X4,Y4, test_size=0.2, random_state=0)
from keras.layers import LSTM

model_lstm = Sequential()
model_lstm.add(
    LSTM(64,return_sequences=True,input_shape = (X_train4.shape[1],1))) #64 lstm neuron block
model_lstm.add(
    LSTM(64, return_sequences= False))
model_lstm.add(Dense(32))
model_lstm.add(Dense(1))
model_lstm.compile(loss = "mean_squared_error", optimizer = "adam", metrics = ["MeanSquaredError"])
history2 = model_lstm.fit(X_train4, Y_train4, epochs = 400, batch_size = 10)

# %%
test_loss, test_mse = model_lstm.evaluate(X_test4, Y_test4)

print("Test mean squared error:", test_mse)

# %%
Y_pred = model_lstm.predict(X_test4)
Y_pred
import numpy as np
Y_pred = model_lstm.predict(X_test4)
result = np.concatenate((X_test4, Y_pred), axis=1)
result

# %%
import pandas as pd
dataset4=pd.read_csv('/content/r3 - Sheet1.csv')
dataset4=dataset4.drop(['noq'], axis=1)
X4=dataset4.iloc[:,:-1].values
Y4=dataset4.iloc[:,-1].values

# %%
import numpy as np

X4 = np.array(X4)
Y4 = np.array(Y4)
